# %% [markdown]
# <a href="https://colab.research.google.com/github/imai-ry/colabo/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch 
torch.cuda.get_device_name(0)
# Out:
# 'Tesla K80'
